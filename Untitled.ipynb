# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 import pickle
#       3 with open('crop_model.pkl', 'wb') as f:
# ----> 4     pickle.dump(rf, f)
#       6 with open('scaler.pkl', 'wb') as f:
#       7     pickle.dump(scaler, f)
#
# NameError: name 'rf' is not defined
